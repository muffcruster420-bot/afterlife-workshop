# %%
a='https://github.com/'

# %%
b='jesses-code-'

# %%
c='adventures/'

# %%
d='afterlife-workshop.git'

# %%
import os
os.system('git clone '+a+b+c+d)
# Out:
# 32768

# %%
# %cd afterlife-workshop
# Out:
# [Errno 2] No such file or directory: 'afterlife-workshop'
# /content

# %%
# !pip -q install mne

# %%
# !python analyze_transition.py
# Out:
# python3: can't open file '/content/analyze_transition.py': [Errno 2] No such file or directory

# %%
a='https://github.com/'
b='muffcruster420-'
c='bot/'
d='afterlife-workshop.git'
import os
os.system('git clone '+a+b+c+d)
# Out:
# 0

# %%
# %cd afterlife-workshop
# Out:
# /content/afterlife-workshop

# %%
# !python analyze_transition.py
# Out:
# Figures generated: figure1_gap.png, figure2_transition.png, figure3_tesla.png
# {
#   "sleep": 0.187,
#   "subject3": 0.19,
#   "dying": 0.771,
#   "threshold": 0.65,
#   "hold_time": 87.0
# }

# %%
# !ls
# Out:
# ABSTRACT.md		     generate_plots.py	  real_data
# afterlife-workshop	     GETTING_STARTED.md   requirements.txt
# afterlife_workshop_map.html  index.html		  run_bicoherence.py
# analyze_transition.py	     interim_plot.png	  run_theta_gamma_pac.py
# CHANGELOG.md		     LICENSE		  SC4001EC-Hypnogram.edf
# CITATION.cff		     PAPER.md		  scripts
# docs			     PREREGISTRATION.md   sleep_pac.png
# dying_pac.txt		     PREREG.md		  sleep_pac.txt
# figure1_gap.png		     quick_test.py	  subjects_metadata.csv
# figure2_transition.png	     README.md		  test_bicoherence.py
# figure3_tesla.png	     real_bicoherence.py  THREAD.md

# %%
# !ls
# Out:
# ABSTRACT.md		     generate_plots.py	  real_data
# afterlife-workshop	     GETTING_STARTED.md   requirements.txt
# afterlife_workshop_map.html  index.html		  run_bicoherence.py
# analyze_transition.py	     interim_plot.png	  run_theta_gamma_pac.py
# CHANGELOG.md		     LICENSE		  SC4001EC-Hypnogram.edf
# CITATION.cff		     PAPER.md		  scripts
# docs			     PREREGISTRATION.md   sleep_pac.png
# dying_pac.txt		     PREREG.md		  sleep_pac.txt
# figure1_gap.png		     quick_test.py	  subjects_metadata.csv
# figure2_transition.png	     README.md		  test_bicoherence.py
# figure3_tesla.png	     real_bicoherence.py  THREAD.md

# %%
from IPython.display import Image
Image('figure1_gap.png')

# %%
# %cd afterlife-workshop
# Out:
# /content/afterlife-workshop/afterlife-workshop

# %%
from IPython.display import Image
Image('figure1_gap.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/display.py in _data_and_metadata(self, always_both)
#    1299         try:
# -> 1300             b64_data = b2a_base64(self.data).decode('ascii')
#    1301         except TypeError:
#
# TypeError: a bytes-like object is required, not 'str'
#
# During handling of the above exception, another exception occurred:
#
# FileNotFoundError                         Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/IPython/core/formatters.py in __call__(self, obj, include, exclude)
#     968
#     969             if method is not None:
# --> 970                 return method(include=include, exclude=exclude)
#     971             return None
#     972         else:
#
# ...

# %%
# !zip -r results.zip *.png *.txt
# Out:
# 	zip warning: name not matched: *.png
# 	zip warning: name not matched: *.txt
#
# zip error: Nothing to do! (try: zip -r results.zip . -i *.png *.txt)

# %%
import os
os.chdir('/content/afterlife-workshop')

# !zip -r /content/results.zip figure1_gap.png figure2_transition.png figure3_tesla.png dying_pac.txt

from google.colab import files
files.download('/content/results.zip')
# Out:
#   adding: figure1_gap.png (deflated 22%)
#   adding: figure2_transition.png (deflated 8%)
#   adding: figure3_tesla.png (deflated 6%)
#   adding: dying_pac.txt (deflated 38%)

# %%
# %cd /content/afterlife-workshop
# Out:
# /content/afterlife-workshop/afterlife-workshop

# %%
# !ls
# Out:
# ABSTRACT.md		     generate_plots.py	  real_data
# afterlife-workshop	     GETTING_STARTED.md   requirements.txt
# afterlife_workshop_map.html  index.html		  run_bicoherence.py
# analyze_transition.py	     interim_plot.png	  run_theta_gamma_pac.py
# CHANGELOG.md		     LICENSE		  SC4001EC-Hypnogram.edf
# CITATION.cff		     PAPER.md		  scripts
# docs			     PREREGISTRATION.md   sleep_pac.png
# dying_pac.txt		     PREREG.md		  sleep_pac.txt
# figure1_gap.png		     quick_test.py	  subjects_metadata.csv
# figure2_transition.png	     README.md		  test_bicoherence.py
# figure3_tesla.png	     real_bicoherence.py  THREAD.md

# %%
# !zip results.zip *.png *.txt
# Out:
#   adding: figure1_gap.png (deflated 22%)
#   adding: figure2_transition.png (deflated 8%)
#   adding: figure3_tesla.png (deflated 6%)
#   adding: interim_plot.png (deflated 11%)
#   adding: sleep_pac.png (deflated 25%)
#   adding: dying_pac.txt (deflated 38%)
#   adding: requirements.txt (stored 0%)
#   adding: sleep_pac.txt (stored 0%)

# %%
from google.colab import files
files.download('results.zip')

# %%
# %cd /content/afterlife-workshop
# !git config user.email "jesse@users.noreply.github.com"
# !git config user.name "muffcruster420-bot"
# Out:
# /content/afterlife-workshop/afterlife-workshop

# %%
# !git add figure1_gap.png figure2_transition.png figure3_tesla.png

# %%
# !git commit -m "Add Shangraw Gap: living 0.19 vs dying 0.77"
# Out:
# [main bb91ba8] Add Shangraw Gap: living 0.19 vs dying 0.77
#  3 files changed, 0 insertions(+), 0 deletions(-)
#  rewrite figure1_gap.png (99%)
#  rewrite figure2_transition.png (98%)

# %%
# !git push https://PASTE_YOUR_TOKEN_HERE@github.com/muffcruster420-bot/afterlife-workshop.git HEAD:main
# Out:
# fatal: could not read Password for 'https://PASTE_YOUR_TOKEN_HERE@github.com': No such device or address

# %%
# !rm -rf afterlife-workshop

# %%
from getpass import getpass
TOKEN = getpass('token:')
url = f"https://{TOKEN}@github.com/muffcruster420-bot/afterlife-workshop.git"
# !rm -rf /content/afterlife-workshop
# !git clone {url}
# %cd afterlife-workshop
# Out:
# token:··········
# Cloning into 'afterlife-workshop'...
# remote: Enumerating objects: 269, done.
# remote: Counting objects: 100% (59/59), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 269 (delta 18), reused 48 (delta 9), pack-reused 210 (from 2)
# Receiving objects: 100% (269/269), 49.78 MiB | 31.47 MiB/s, done.
# Resolving deltas: 100% (97/97), done.
# /content/afterlife-workshop

# %%
from google.colab import _message; import json
nb = _message.blocking_request('get_ipynb')
open('colab-notebook.ipynb','w').write(json.dumps(nb['ipynb']))
# !git add colab-notebook.ipynb
# !git config user.email "jesse@kingston.ca"
# !git config user.name "muffcruster420"
# !git commit -m "save from phone"
# !git push origin main
